# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.zeros(100)
cp = np.zeros(100)
cp[50] = 1
Q = 0.5
a = 1
for i in range(4,100):
    x[i] = x[i-1] -  x[i-2] +a * x[i-3] -  a * x[i-4]  + np.random.randn() * Q
    if i == 50:
        a = 0

# %%
x = np.zeros(100)
cp = np.zeros(100)
cp[50] = 1
Q = 0.01
for i in range(99):
    x[i+1] = x[i] + np.random.randn() * Q
    if i==50:
        x[i+1] = 0.7

# %%
x = np.zeros(100)
cp = np.zeros(100)
cp[50] = 1
Q = 0.01
for i in range(99):
    x[i+1] = x[i] + np.random.randn() * Q
    if i==50:
        x[i+1] = 0.7

# %%
x = np.zeros(100)
cp = np.zeros(100)
cp[50] = 1
Q = 0.01
for i in range(99):
    x[i+1] = x[i] + np.random.randn() * Q
    if i==50:
        Q = 0.05

# %%
plt.figure(figsize=(16,8))
plt.plot((x-x.min()) / (x.max() - x.min()),label='Data')
plt.stem(cp,'r',label='Model Order Change')
plt.ylim([0.02,1])
plt.legend()
